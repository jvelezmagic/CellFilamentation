# %% [markdown]
# # 1.0 Cell Filamentation

# %% [markdown]
# ## Activate project

# %%
using DrWatson
@quickactivate :CellFilamentation

# %% [markdown]
# ## Differential equations algorithms

# %%
choice_function(integrator) = (Int(integrator.dt < 0.001) + 1)
alg_switch = CompositeAlgorithm((Tsit5(), Vern7()), choice_function);

# %% [markdown]
# ## Initialize an Cell structure

# %%
cell = Cell(max_height=4.0)
# Out:
# Cell{Float64}
#   side_length: Float64 0.6
#   radius: Float64 0.2
#   internal_toxin: Float64 0.0
#   toxin_diffusion_rate: Float64 0.3
#   antitoxin: Float64 0.0
#   antitoxin_efficacy: Float64 0.0
#   filamentation_rate: Float64 0.1
#   filamentation_threshold: Float64 0.5
#   kill_threshold: Float64 1.0
#   max_height: Float64 4.0
#   noise_int_toxin: Float64 0.1
#   noise_height: Float64 0.0
#   τ_filamentation: Float64 Inf
#   τ_kill: Float64 Inf
#   τ_delay: Float64 0.0
#   state: Symbol Normal
# WARNING: both DifferentialEquations and DataFramesMeta export "flatten"; uses of it in module CellFilamentation must be qualified
# WARNING: both Interpolations and Distributions export "scale"; uses of it in module CellFilamentation must be qualified

# %% [markdown]
# ## Simulate filamentation

# %% [markdown]
# ### Toxin ramp

# %%
t, toxin = toxin_entry(10, 100, 100, 5, false);

Random.seed!(1234)
filamentation_plot = simulation_plot(cell, t, toxin, 100)

# %%
savefig(filamentation_plot, plotsdir("filamentation_model_ramp_signal.png"))
savefig(filamentation_plot, plotsdir("filamentation_model_ramp_signal.svg"))

# %% [markdown]
# ### Toxin stable

# %%
t2, toxin2 = toxin_entry(10, 100, 100, 1.0, true);

Random.seed!(1234)
filamentation_plot2 = simulation_plot(cell, t2, toxin2, 100)

# %%
savefig(filamentation_plot2, plotsdir("filamentation_model_stable_signal.png"))
savefig(filamentation_plot2, plotsdir("filamentation_model_stable_signal.svg"))
